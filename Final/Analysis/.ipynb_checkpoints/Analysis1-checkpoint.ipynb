# %% [markdown]
# ## 1. <font color='red'>

# %%
import os                            #importng os library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas import DataFrame
import numpy as np
import matplotlib
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
# %matplotlib inline

# %%
path=os.chdir("..")                   #Moving back one folder

# %%
path=os.getcwd()                          #Checking the path
path
# Out:
# 'C:\\DataAnalysis4Python\\kanakia_dhruv_spring2017\\Final'

# %%
final_path= path+"\\Data\\movie_metadata.csv" #setting up the final path in final_path

# %%
df= pd.read_csv(final_path)
df.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
df1=df.dropna()                         #dropping all the NA values
#df1.head()

# %%
df1.to_csv('null.csv', sep=',')

# %%
df_year=df1.groupby('title_year')['movie_title'].count()

# %%
df_year_count= df_year.to_frame().reset_index()

# %%
df_year_count.head()
# Out:
#    title_year  movie_title
# 0      1927.0            1
# 1      1929.0            1
# 2      1933.0            1
# 3      1935.0            1
# 4      1936.0            1

# %% [markdown]
# ## <font color='red'> 1. Finding out in which year range the number of films in the dataset is the most </font>

# %%
df_year_count.plot(x='title_year',y='movie_title',kind='line')

# %% [markdown]
# ## <font color='Green'>CONCLUSION:The dataset has the highest number of films between the year 2000-2020  </font>

# %% [markdown]
# ## imdb over years

# %%
df_imdb_year=df1.groupby('title_year' ,as_index=False)['imdb_score'].mean()

# %%
df_imdb_year.plot(x='title_year', y='imdb_score', kind='line', cmap='copper')

# %% [markdown]
# ## It has no direct pattern but can surely see increase in number of films has caused decrease in quality. More quantity less quality

# %%
df_movies_year_gross = df1.groupby(['title_year'], as_index=False)['gross'].sum()
#df_movies_year_gross.head()

# %%
df_year_count= df_year_count.merge(df_movies_year_gross)

# %%
#df_year_count.head()

# %%
df_year_count[['title_year','gross']] = df_year_count[['title_year','gross']].apply(pd.to_numeric)

# %%
df_year_count.head()
# Out:
#    title_year  movie_title      gross
# 0      1927.0            1    26435.0
# 1      1929.0            1  2808000.0
# 2      1933.0            1  2300000.0
# 3      1935.0            1  3000000.0
# 4      1936.0            1   163245.0

# %%
df_year_count['Average']= df_year_count['gross']/df_year_count['movie_title']

# %%
df_year_count= df_year_count[(df_year_count.title_year> 1980)]

# %%
df_year_count.head()
# Out:
#     title_year  movie_title         gross       Average
# 38      1981.0           17  7.048333e+08  4.146078e+07
# 39      1982.0           16  1.200601e+09  7.503755e+07
# 40      1983.0           13  8.922934e+08  6.863795e+07
# 41      1984.0           23  1.447611e+09  6.293960e+07
# 42      1985.0           15  8.883470e+08  5.922313e+07

# %%
df_year_count.plot(x='title_year', y='gross', kind='line', )

# %% [markdown]
# ## Revenue Plot

# %%
df_movies_year_budget = df1.groupby(['title_year'], as_index=False)['budget'].sum()
df_movies_year_budget.head()
# Out:
#    title_year     budget
# 0      1927.0  6000000.0
# 1      1929.0   379000.0
# 2      1933.0   439000.0
# 3      1935.0   609000.0
# 4      1936.0  1500000.0

# %%
df_year_count_budget= df_year_count.merge(df_movies_year_budget)

# %%
df_year_count_budget[['title_year','budget']] = df_year_count_budget[['title_year','budget']].apply(pd.to_numeric)

# %%
df_year_count_budget['Average_Budget']= df_year_count['budget']/df_year_count['movie_title']

# %%
df_year_count_budget= df_year_count_budget[(df_year_count_budget.title_year> 1980)]

# %%
df_year_count.plot(x='title_year', y='budget', kind='line', )

# %% [markdown]
# ## Can see there is a pattern between the three plots i.e IMDB_Score vs Budget vs Gross pver the years. To get a better idea we will plot a 3-d interactive plot

# %% [markdown]
# #### since it is an interactive plot we will have to run matplotlib notebook just for this plot.

# %%
# %matplotlib notebook

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(10,5)).gca(projection='3d')
#ax = fig.add_subplot(111, projection='3d')
x =df1['imdb_score']
y =df1['budget']
z =df1['gross']



fig.scatter(x, y, z)

fig.set_xlabel('imdb score')
fig.set_ylabel('Budget')
fig.set_zlabel('Gross')

plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ## The above plot clearly indicates that imdb and gross(revenue) are directly related. With increase in IMDB

# %% [markdown]
# ## Q. Is budget directly related to profit?

# %%
df2 = df[np.isfinite(df['budget'])]

# %%
df2=df2[np.isfinite(df2['gross'])]

# %%
df2['net']= df2['gross']-df2['budget']
#df_2006['Net']= df_2006['gross']-df_2006['budget']
df2['net_percentage']= df2['net']/df2['budget']
df2['net_percentage']= df2['net_percentage']*100

# %%
df2
# Out:
#                  color       director_name  num_critic_for_reviews  duration  \
# 0                Color       James Cameron                   723.0     178.0
# 1                Color      Gore Verbinski                   302.0     169.0
# 2                Color          Sam Mendes                   602.0     148.0
# 3                Color   Christopher Nolan                   813.0     164.0
# 5                Color      Andrew Stanton                   462.0     132.0
# 6                Color           Sam Raimi                   392.0     156.0
# 7                Color        Nathan Greno                   324.0     100.0
# 8                Color         Joss Whedon                   635.0     141.0
# 9                Color         David Yates                   375.0     153.0
# 10               Color         Zack Snyder                   673.0     183.0
# 11               Color        Bryan Singer                   434.0     169.0
# 12               Color        Marc Forster                   403.0     106.0
# 13               Color      Gore Verbinski                   313.0     151.0
# 14               Color      Gore Verbinski                   450.0     150.0
# 15               Color         Zack Snyder                   733.0     143.0
# 16               Color      Andrew Adamson                   258.0     150.0
# 17               Color         Joss Whedon                   703.0     173.0
# 18               Color        Rob Marshall                   448.0     136.0
# 19               Color    Barry Sonnenfeld                   451.0     106.0
# 20               Color       Peter Jackson                   422.0     164.0
# 21               Color           Marc Webb                   599.0     153.0
# 22               Color        Ridley Scott                   343.0     156.0
# 23               Color       Peter Jackson                   509.0     186.0
# 24               Color         Chris Weitz                   251.0     113.0
# 25               Color       Peter Jackson                   446.0     201.0
# 26               Color       James Cameron                   315.0     194.0
# 27               Color       Anthony Russo                   516.0     147.0
# 28               Color          Peter Berg                   377.0     131.0
# 29               Color     Colin Trevorrow                   644.0     124.0
# 30               Color          Sam Mendes                   750.0     143.0
# ...                ...                 ...                     ...       ...
# 4959             Color     Robert Townsend                    21.0      81.0
# 4962   Black and White       Larry Blamire                    88.0      90.0
# 4964             Color           E.L. Katz                   193.0      88.0
# 4971             Color      Dennis Iliadis                   241.0     114.0
# 4973   Black and White    Darren Aronofsky                   138.0      84.0
# 4975             Color     Myles Berkowitz                    32.0      87.0
# 4977             Color     Morgan Spurlock                   193.0     100.0
# 4978             Color       Brandon Trost                    66.0      82.0
# 4979             Color        Joe Swanberg                    65.0      82.0
# 4984             Color        Edward Burns                    36.0      98.0
# 4987             Color         Lena Dunham                   113.0      98.0
# 4997             Color  David Gordon Green                    75.0      90.0
# 4998             Color        Kevin Jordan                    21.0      90.0
# 5004             Color          Mike Bruce                     3.0      78.0
# 5008   Black and White         Kevin Smith                   136.0     102.0
# 5009             Color       James Bidgood                     8.0      65.0
# 5011             Color         Neil LaBute                    80.0      97.0
# 5012             Color          David Ayer                   233.0     109.0
# 5015   Black and White   Richard Linklater                    61.0     100.0
# 5021             Color         Jay Duplass                    51.0      85.0
# 5023             Color          Daryl Wein                    22.0      88.0
# 5025             Color         John Waters                    73.0     108.0
# 5026             Color     Olivier Assayas                    81.0     110.0
# 5027             Color        Jafar Panahi                    64.0      90.0
# 5029             Color    Kiyoshi Kurosawa                    78.0     111.0
# 5033             Color       Shane Carruth                   143.0      77.0
# 5034             Color    Neill Dela Llana                    35.0      80.0
# 5035             Color    Robert Rodriguez                    56.0      81.0
# 5037             Color        Edward Burns                    14.0      95.0
# 5042             Color            Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes          actor_2_name  \
# 0                         0.0                   855.0      Joel David Moore
# 1                       563.0                  1000.0         Orlando Bloom
# 2                         0.0                   161.0          Rory Kinnear
# 3                     22000.0                 23000.0        Christian Bale
# 5                       475.0                   530.0       Samantha Morton
# 6                         0.0                  4000.0          James Franco
# 7                        15.0                   284.0          Donna Murphy
# 8                         0.0                 19000.0     Robert Downey Jr.
# 9                       282.0                 10000.0      Daniel Radcliffe
# 10                        0.0                  2000.0          Lauren Cohan
# 11                        0.0                   903.0         Marlon Brando
# 12                      395.0                   393.0       Mathieu Amalric
# 13                      563.0                  1000.0         Orlando Bloom
# 14                      563.0                  1000.0           Ruth Wilson
# 15                        0.0                   748.0    Christopher Meloni
# 16                       80.0                   201.0  Pierfrancesco Favino
# 17                        0.0                 19000.0     Robert Downey Jr.
# 18                      252.0                  1000.0           Sam Claflin
# 19                      188.0                   718.0     Michael Stuhlbarg
# 20                        0.0                   773.0            Adam Brown
# 21                      464.0                   963.0       Andrew Garfield
# 22                        0.0                   738.0          William Hurt
# 23                        0.0                   773.0            Adam Brown
# 24                      129.0                  1000.0             Eva Green
# 25                        0.0                    84.0    Thomas Kretschmann
# 26                        0.0                   794.0          Kate Winslet
# 27                       94.0                 11000.0    Scarlett Johansson
# 28                      532.0                   627.0   Alexander Skarsgård
# 29                      365.0                  1000.0            Judy Greer
# 30                        0.0                   393.0         Helen McCrory
# ...                       ...                     ...                   ...
# 4959                    467.0                   287.0   Keenen Ivory Wayans
# 4962                     56.0                    56.0            Brian Howe
# 4964                      3.0                   307.0           Ethan Embry
# 4971                     29.0                   616.0         Monica Potter
# 4973                      0.0                   194.0         Clint Mansell
# 4975                      0.0                   153.0          Tom Ardavany
# 4977                    293.0                     0.0        Amanda Kearsan
# 4978                     32.0                   128.0           Sean Whalen
# 4979                    217.0                   442.0           Lena Dunham
# 4984                      0.0                    73.0       Michael McGlone
# 4987                    969.0                   433.0         Merritt Wever
# 4997                    234.0                    15.0           Eddie Rouse
# 4998                      4.0                   113.0        Christa Miller
# 5004                      6.0                    17.0     Kirpatrick Thomas
# 5008                      0.0                   216.0      Brian O'Halloran
# 5009                      0.0                     NaN         Bobby Kendall
# 5011                    119.0                     7.0           Matt Malloy
# 5012                    453.0                   120.0        Martin Donovan
# 5015                      0.0                     0.0     Richard Linklater
# 5021                    157.0                    10.0         Katie Aselton
# 5023                     38.0                   211.0         Heather Burns
# 5025                      0.0                   105.0            Mink Stole
# 5026                    107.0                    45.0        Béatrice Dalle
# 5027                    397.0                     0.0     Nargess Mamizadeh
# 5029                     62.0                     6.0         Anna Nakagawa
# 5033                    291.0                     8.0        David Sullivan
# 5034                      0.0                     0.0       Edgar Tancangco
# 5035                      0.0                     6.0       Peter Marquardt
# 5037                      0.0                   133.0    Caitlin FitzGerald
# 5042                     16.0                    16.0      Brian Herzlinger
#
#       actor_1_facebook_likes        gross  \
# 0                     1000.0  760505847.0
# 1                    40000.0  309404152.0
# 2                    11000.0  200074175.0
# 3                    27000.0  448130642.0
# 5                      640.0   73058679.0
# 6                    24000.0  336530303.0
# 7                      799.0  200807262.0
# 8                    26000.0  458991599.0
# 9                    25000.0  301956980.0
# 10                   15000.0  330249062.0
# 11                   18000.0  200069408.0
# 12                     451.0  168368427.0
# 13                   40000.0  423032628.0
# 14                   40000.0   89289910.0
# 15                   15000.0  291021565.0
# 16                   22000.0  141614023.0
# 17                   26000.0  623279547.0
# 18                   40000.0  241063875.0
# 19                   10000.0  179020854.0
# 20                    5000.0  255108370.0
# 21                   15000.0  262030663.0
# 22                     891.0  105219735.0
# 23                    5000.0  258355354.0
# 24                   16000.0   70083519.0
# 25                    6000.0  218051260.0
# 26                   29000.0  658672302.0
# 27                   21000.0  407197282.0
# 28                   14000.0   65173160.0
# 29                    3000.0  652177271.0
# 30                     883.0  304360277.0
# ...                      ...          ...
# 4959                   467.0    5228617.0
# 4962                   126.0     110536.0
# 4964                  3000.0      59379.0
# 4971                   956.0   32721635.0
# 4973                  1000.0    3216970.0
# 4975                  1000.0     536767.0
# 4977                     0.0   11529368.0
# 4978                   968.0      40557.0
# 4979                 10000.0      30084.0
# 4984                   138.0   10246600.0
# 4987                   969.0     389804.0
# 4997                   552.0     241816.0
# 4998                 20000.0     277233.0
# 5004                    32.0     243768.0
# 5008                   898.0    3151130.0
# 5009                     0.0       8231.0
# 5011                   136.0    2856622.0
# 5012                  1000.0   10499968.0
# 5015                     5.0    1227508.0
# 5021                   830.0     192467.0
# 5023                   331.0      76382.0
# 5025                   462.0     180483.0
# 5026                   576.0     136007.0
# 5027                     5.0     673780.0
# 5029                    89.0      94596.0
# 5033                   291.0     424760.0
# 5034                     0.0      70071.0
# 5035                   121.0    2040920.0
# 5037                   296.0       4584.0
# 5042                    86.0      85222.0
#
#                                                  genres      ...        \
# 0                       Action|Adventure|Fantasy|Sci-Fi      ...
# 1                              Action|Adventure|Fantasy      ...
# 2                             Action|Adventure|Thriller      ...
# 3                                       Action|Thriller      ...
# 5                               Action|Adventure|Sci-Fi      ...
# 6                              Action|Adventure|Romance      ...
# 7     Adventure|Animation|Comedy|Family|Fantasy|Musi...      ...
# 8                               Action|Adventure|Sci-Fi      ...
# 9                      Adventure|Family|Fantasy|Mystery      ...
# 10                              Action|Adventure|Sci-Fi      ...
# 11                              Action|Adventure|Sci-Fi      ...
# 12                                     Action|Adventure      ...
# 13                             Action|Adventure|Fantasy      ...
# 14                             Action|Adventure|Western      ...
# 15                      Action|Adventure|Fantasy|Sci-Fi      ...
# 16                      Action|Adventure|Family|Fantasy      ...
# 17                              Action|Adventure|Sci-Fi      ...
# 18                             Action|Adventure|Fantasy      ...
# 19        Action|Adventure|Comedy|Family|Fantasy|Sci-Fi      ...
# 20                                    Adventure|Fantasy      ...
# 21                             Action|Adventure|Fantasy      ...
# 22                       Action|Adventure|Drama|History      ...
# 23                                    Adventure|Fantasy      ...
# 24                             Adventure|Family|Fantasy      ...
# 25                       Action|Adventure|Drama|Romance      ...
# 26                                        Drama|Romance      ...
# 27                              Action|Adventure|Sci-Fi      ...
# 28                     Action|Adventure|Sci-Fi|Thriller      ...
# 29                     Action|Adventure|Sci-Fi|Thriller      ...
# 30                            Action|Adventure|Thriller      ...
# ...                                                 ...      ...
# 4959                                             Comedy      ...
# 4962                               Comedy|Horror|Sci-Fi      ...
# 4964                 Comedy|Crime|Drama|Horror|Thriller      ...
# 4971                              Crime|Horror|Thriller      ...
# 4973                             Drama|Mystery|Thriller      ...
# 4975                           Biography|Comedy|Romance      ...
# 4977                           Comedy|Documentary|Drama      ...
# 4978                                             Comedy      ...
# 4979                                       Comedy|Drama      ...
# 4984                               Comedy|Drama|Romance      ...
# 4987                               Comedy|Drama|Romance      ...
# 4997                                              Drama      ...
# 4998                                     Comedy|Romance      ...
# 5004                                            Western      ...
# 5008                                             Comedy      ...
# 5009                                      Drama|Fantasy      ...
# 5011                                       Comedy|Drama      ...
# 5012                        Action|Crime|Drama|Thriller      ...
# 5015                                       Comedy|Drama      ...
# 5021                               Comedy|Drama|Romance      ...
# 5023                                            Romance      ...
# 5025                                Comedy|Crime|Horror      ...
# 5026                                Drama|Music|Romance      ...
# 5027                                              Drama      ...
# 5029                      Crime|Horror|Mystery|Thriller      ...
# 5033                              Drama|Sci-Fi|Thriller      ...
# 5034                                           Thriller      ...
# 5035                Action|Crime|Drama|Romance|Thriller      ...
# 5037                                       Comedy|Drama      ...
# 5042                                        Documentary      ...
#
#           country content_rating       budget  title_year  \
# 0             USA          PG-13  237000000.0      2009.0
# 1             USA          PG-13  300000000.0      2007.0
# 2              UK          PG-13  245000000.0      2015.0
# 3             USA          PG-13  250000000.0      2012.0
# 5             USA          PG-13  263700000.0      2012.0
# 6             USA          PG-13  258000000.0      2007.0
# 7             USA             PG  260000000.0      2010.0
# 8             USA          PG-13  250000000.0      2015.0
# 9              UK             PG  250000000.0      2009.0
# 10            USA          PG-13  250000000.0      2016.0
# 11            USA          PG-13  209000000.0      2006.0
# 12             UK          PG-13  200000000.0      2008.0
# 13            USA          PG-13  225000000.0      2006.0
# 14            USA          PG-13  215000000.0      2013.0
# 15            USA          PG-13  225000000.0      2013.0
# 16            USA             PG  225000000.0      2008.0
# 17            USA          PG-13  220000000.0      2012.0
# 18            USA          PG-13  250000000.0      2011.0
# 19            USA          PG-13  225000000.0      2012.0
# 20    New Zealand          PG-13  250000000.0      2014.0
# 21            USA          PG-13  230000000.0      2012.0
# 22            USA          PG-13  200000000.0      2010.0
# 23            USA          PG-13  225000000.0      2013.0
# 24            USA          PG-13  180000000.0      2007.0
# 25    New Zealand          PG-13  207000000.0      2005.0
# 26            USA          PG-13  200000000.0      1997.0
# 27            USA          PG-13  250000000.0      2016.0
# 28            USA          PG-13  209000000.0      2012.0
# 29            USA          PG-13  150000000.0      2015.0
# 30             UK          PG-13  200000000.0      2012.0
# ...           ...            ...          ...         ...
# 4959          USA              R     100000.0      1987.0
# 4962          USA             PG      40000.0      2001.0
# 4964          USA      Not Rated     200000.0      2013.0
# 4971          USA              R   15000000.0      2009.0
# 4973          USA              R      60000.0      1998.0
# 4975          USA              R      60000.0      1998.0
# 4977          USA             PG      65000.0      2004.0
# 4978          USA              R      60000.0      2011.0
# 4979          USA              R      70000.0      2014.0
# 4984          USA              R      25000.0      1995.0
# 4987          USA      Not Rated      65000.0      2010.0
# 4997          USA        Unrated      42000.0      2000.0
# 4998          USA              R      40000.0      1999.0
# 5004          USA              R      30000.0      2007.0
# 5008          USA              R     230000.0      1994.0
# 5009          USA      Not Rated      27000.0      1971.0
# 5011       Canada              R      25000.0      1997.0
# 5012          USA              R   35000000.0      2014.0
# 5015          USA              R      23000.0      1991.0
# 5021          USA              R      15000.0      2005.0
# 5023          USA            NaN      15000.0      2009.0
# 5025          USA          NC-17      10000.0      1972.0
# 5026       France              R       4500.0      2004.0
# 5027         Iran      Not Rated      10000.0      2000.0
# 5029        Japan            NaN    1000000.0      1997.0
# 5033          USA          PG-13       7000.0      2004.0
# 5034  Philippines      Not Rated       7000.0      2005.0
# 5035          USA              R       7000.0      1992.0
# 5037          USA      Not Rated       9000.0      2011.0
# 5042          USA             PG       1100.0      2004.0
#
#      actor_2_facebook_likes  imdb_score aspect_ratio movie_facebook_likes  \
# 0                     936.0         7.9         1.78                33000
# 1                    5000.0         7.1         2.35                    0
# 2                     393.0         6.8         2.35                85000
# 3                   23000.0         8.5         2.35               164000
# 5                     632.0         6.6         2.35                24000
# 6                   11000.0         6.2         2.35                    0
# 7                     553.0         7.8         1.85                29000
# 8                   21000.0         7.5         2.35               118000
# 9                   11000.0         7.5         2.35                10000
# 10                   4000.0         6.9         2.35               197000
# 11                  10000.0         6.1         2.35                    0
# 12                    412.0         6.7         2.35                    0
# 13                   5000.0         7.3         2.35                 5000
# 14                   2000.0         6.5         2.35                48000
# 15                   3000.0         7.2         2.35               118000
# 16                    216.0         6.6         2.35                    0
# 17                  21000.0         8.1         1.85               123000
# 18                  11000.0         6.7         2.35                58000
# 19                    816.0         6.8         1.85                40000
# 20                    972.0         7.5         2.35                65000
# 21                  10000.0         7.0         2.35                56000
# 22                    882.0         6.7         2.35                17000
# 23                    972.0         7.9         2.35                83000
# 24                   6000.0         6.1         2.35                    0
# 25                    919.0         7.2         2.35                    0
# 26                  14000.0         7.7         2.35                26000
# 27                  19000.0         8.2         2.35                72000
# 28                  10000.0         5.9         2.35                44000
# 29                   2000.0         7.0         2.00               150000
# 30                    563.0         7.8         2.35                80000
# ...                     ...         ...          ...                  ...
# 4959                  322.0         7.0         1.85                  471
# 4962                   76.0         7.0         1.85                    0
# 4964                  982.0         6.8         2.35                    0
# 4971                  878.0         6.6         1.85                    0
# 4973                  512.0         7.5         1.66                24000
# 4975                  184.0         5.3         1.85                   30
# 4977                    0.0         7.3         1.78                    0
# 4978                  407.0         5.6         2.35                    0
# 4979                  969.0         5.6         1.85                  812
# 4984                  111.0         6.6         1.85                  265
# 4987                  529.0         6.3         2.35                    0
# 4997                   61.0         7.5         2.35                  451
# 4998                  467.0         7.6         1.85                    0
# 5004                   17.0         4.1         2.35                   13
# 5008                  657.0         7.8         1.37                    0
# 5009                    0.0         6.7         1.37                   85
# 5011                  108.0         7.3         1.85                  489
# 5012                  206.0         5.7         1.85                10000
# 5015                    0.0         7.1         1.37                 2000
# 5021                  224.0         6.6          NaN                  297
# 5023                  212.0         6.2         2.35                  324
# 5025                  143.0         6.1         1.37                    0
# 5026                  133.0         6.9         2.35                  171
# 5027                    0.0         7.5         1.85                  697
# 5029                   13.0         7.4         1.85                  817
# 5033                   45.0         7.0         1.85                19000
# 5034                    0.0         6.3          NaN                   74
# 5035                   20.0         6.9         1.37                    0
# 5037                  205.0         6.4          NaN                  413
# 5042                   23.0         6.6         1.85                  456
#
#               net net_percentage
# 0     523505847.0     220.888543
# 1       9404152.0       3.134717
# 2     -44925825.0     -18.337071
# 3     198130642.0      79.252257
# 5    -190641321.0     -72.294775
# 6      78530303.0      30.438102
# 7     -59192738.0     -22.766438
# 8     208991599.0      83.596640
# 9      51956980.0      20.782792
# 10     80249062.0      32.099625
# 11     -8930592.0      -4.273011
# 12    -31631573.0     -15.815787
# 13    198032628.0      88.014501
# 14   -125710090.0     -58.469809
# 15     66021565.0      29.342918
# 16    -83385977.0     -37.060434
# 17    403279547.0     183.308885
# 18     -8936125.0      -3.574450
# 19    -45979146.0     -20.435176
# 20      5108370.0       2.043348
# 21     32030663.0      13.926375
# 22    -94780265.0     -47.390132
# 23     33355354.0      14.824602
# 24   -109916481.0     -61.064712
# 25     11051260.0       5.338773
# 26    458672302.0     229.336151
# 27    157197282.0      62.878913
# 28   -143826840.0     -68.816670
# 29    502177271.0     334.784847
# 30    104360277.0      52.180138
# ...           ...            ...
# 4959    5128617.0    5128.617000
# 4962      70536.0     176.340000
# 4964    -140621.0     -70.310500
# 4971   17721635.0     118.144233
# 4973    3156970.0    5261.616667
# 4975     476767.0     794.611667
# 4977   11464368.0   17637.489231
# 4978     -19443.0     -32.405000
# 4979     -39916.0     -57.022857
# 4984   10221600.0   40886.400000
# 4987     324804.0     499.698462
# 4997     199816.0     475.752381
# 4998     237233.0     593.082500
# 5004     213768.0     712.560000
# 5008    2921130.0    1270.056522
# 5009     -18769.0     -69.514815
# 5011    2831622.0   11326.488000
# 5012  -24500032.0     -70.000091
# 5015    1204508.0    5236.991304
# 5021     177467.0    1183.113333
# 5023      61382.0     409.213333
# 5025     170483.0    1704.830000
# 5026     131507.0    2922.377778
# 5027     663780.0    6637.800000
# 5029    -905404.0     -90.540400
# 5033     417760.0    5968.000000
# 5034      63071.0     901.014286
# 5035    2033920.0   29056.000000
# 5037      -4416.0     -49.066667
# 5042      84122.0    7647.454545
#
# [3891 rows x 30 columns]

# %%
# %matplotlib inline

# %%
df3=df2.groupby(['title_year'], as_index=False)['net'].max()

# %%
df3.plot(x='title_year',y='net', kind='line')
# Out:
# <img src="data:image/png;base64,...">

# %%
df2.plot(x='budget',y='net',kind='scatter', xlim=(0000000000,500000000), ylim=(-200000000,700000000))

# %%
df_budget_net=( df2[['net','budget']].corr())
df_budget_net
# Out:
#              net    budget
# net     1.000000 -0.951709
# budget -0.951709  1.000000

# %% [markdown]
# ## CONCLUSION:
# ### 1. FROM the above graph you can clearly see that's not the case. YES, there are instances when net profit has reached highest point for few high budget movies. But, the general trend shows that it mostly decreases with increase in budget
# ### 2. Even the Coorelation proves that net and budget are nit directly related

# %% [markdown]
# ## WITH WHICH FACTOS IS PROFIT ACTUALLY RELATED IN THE DATASET?

# %%
corr = df2.corr()

# %%
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# %%
f, ax = plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap='RdYlBu', vmax=1,
            square=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)

# %% [markdown]
# ## Conclusion: Net and Net percentage does not have any direct relation with any of the other element.

# %% [markdown]
# ## <font color='red'> 2. For the year range 2000-2020 we will find out what was their gross and budget </font>

# %%
df_gross_years= df1[(df1['title_year']>2000.0)&(df1['title_year']<2020.0)]

# %%
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 5                    475.0                   530.0   Samantha Morton
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 5                   640.0   73058679.0          Action|Adventure|Sci-Fi
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 5         ...                         738.0  English      USA           PG-13
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 5  263700000.0      2012.0                  632.0        6.6          2.35
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 5                24000
#
# [5 rows x 28 columns]

# %%
df_gross_years1=df_gross_years.groupby('title_year')['movie_title'].count()

# %%
df_sort= df1.loc[:,['title_year','budget']]
df_sort.sort_values(by='budget', ascending=False).head()
# Out:
#       title_year        budget
# 2988      2006.0  1.221550e+10
# 3859      2005.0  4.200000e+09
# 3005      2005.0  2.500000e+09
# 2323      1997.0  2.400000e+09
# 2334      2004.0  2.127520e+09

# %%
df_gross_years1.plot(kind='bar')

# %%
df_gross= df_gross_years.groupby('title_year')['budget','gross'].sum().plot.barh(stacked=True)
df_gross1= df_gross_years.groupby('title_year')['budget','gross'].sum()

# %% [markdown]
# ##  <font color='green'> Conclusion: Stacked Bar plot shows following results:
# 1. The budget of movies increased significantly from 2004 upto 2006. Highest being in 2016.
# 2. Number of movies released in 2006 was almost equal to 2002,2004,2005,2008,2009 but the budgetin 2006 was quite    high. Comparing the the gross 2006 had the lowest gross which indicates many high budget films didn't do well in the box office.
# 3. From the dataframe(df_sort) we can clearly see that the top budget films are between 2005 aqnd 2006.
#
#
# </font>

# %% [markdown]
# ## Which country has the highest number of movies?

# %%
df_num_movies_country= df1.groupby(['country'])['movie_title'].count().reset_index()

# %%
df_num_movies_country.head()
# Out:
#        country  movie_title
# 0  Afghanistan            1
# 1    Argentina            3
# 2        Aruba            1
# 3    Australia           39
# 4      Belgium            1

# %%
df_num_movies_country.plot(x='country',y ='movie_title', kind='bar', ylim=(0,400), figsize=(10,5))

# %% [markdown]
# ### USA leads with the most number of films in the dataset. The big 5 are USA, UK, Germany, France and Canada.
# ### We will now figure out which language is the most used in the database

# %%
df_num_lan= df1.groupby(['language'])['movie_title'].count().reset_index()

# %%
df_num_lan.plot(x='language',y='movie_title', kind='bar', ylim=(0,400))

# %% [markdown]
# ## ENglish is the highest use language in the dataset followed by French, Spanish, Mandarian and Japanese
