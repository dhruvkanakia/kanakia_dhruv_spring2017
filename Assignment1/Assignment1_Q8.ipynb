# %% [markdown]
# Question 8
# Use nps_chat and wordlist corpus.
# If you find a word in nps_chat but not in wordlist, it is considered an unusual word. (e.g. Heyyyy, gr8, 4ever can be considered unusual words for this analysis)
# Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# Bonus: What if I want to count : ) , : ( all these emoticons in. (optional)

# %%
import nltk
nltk.corpus.nps_chat.fileids()
a=[]
for b in nltk.corpus.nps_chat.fileids():
    text = nltk.corpus.nps_chat.words(b)
    c=text
    a.append(c)
d=sum(a,[]) 
d=list(set([i.lower() for i in d]))
print(len(d))
# Out:
# 5441

# %%
List=nltk.corpus.words.words()
List=list(set([i.lower() for i in List]))
#print(len(List))
Unusual_list=list(set(d)-set(List))
User_List=[]
for a in Unusual_list:
    if a.startswith('u'): 
        for i in a:
            if i.isdigit():
                UsersList.append(a)
                break
Unusual_words=list(set(Unusual_list)-set(User_List))              
print(Unusual_words)
# Out:
# ['', 'n e', 'hhehe', '. . .', 'vanished', 'hartford', 'peolpe', "y'", "martini's", 'pfft', '"s', '<33333333333333333', 'chunks', 'thanx', 'gezzz', 'trippin', '~!', 'evertonr', '!!!!!!!!!', 'pictures', 'dyed', '?..', '.:', 'sites', 'typed', 'bears', 'mp3', 'nicks', 'k-mart', 'tok', '#talkcity-20s', 'okay', 'weeeeeeeeeeeeeeeeeeeeeeeeed', 'aol.com', '39.3', 'rooms', 'grea', 'cheeeez', 'subsitute', '5', 'descriminate', 'chattin', 'bc', 'llloooozzzzeeerrrrzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzzz', 'nite', 'fock', 'scuba', 'plays', 'u75', 'kennedy', 'cuppers', 'forwads', 'reschedual', 'comments', 'knocked', 'jrz', '(((((..', 'borat', 'laughin', 'dontcha', 'un-freeze', 'joshy', 'moanin', 'breaks', 'paragraphs', 'nicer', 'deaths', 'cops', 'bouts', 'hahahahahahaha', 'pm', 'ogan', 'ahh', 'wishes', 'brb', 'stationed', 'chops', '2:55', '-o', 'tryina', 'kisses', '73%', ':p', 'bounced', 'denzel', ':tongue:', 'lix', 'shhhh', 'cries', '29803', 'oops', '21', 'futurama', 'u181', '))))))))))))
# ...
